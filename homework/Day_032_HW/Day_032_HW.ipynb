# %% [markdown]
# ## 練習時間
#
# 相信大家目前都能夠初步了解機器學習專案的流程及步驟，今天的作業希望大家能夠看看全球機器學習巨頭們在做的機器學習專案。以 google 為例，下圖是 Google 內部專案使用機器學習的數量，隨著時間進展，現在早已超過 2000 個專案在使用 ML。
#
# ![img](https://cdn-images-1.medium.com/max/800/1*U_L8qI8RmYS-MOBrYvXhSA.png)

# %% [markdown]
# ## 請至以下機器學習巨頭的 blog 參觀，試著閱讀一篇文章並分析其
#
# ### 作業 1：目標 (要解決什麼問題）
#
# ### 作業 2：方法 / 使用的技術 (只需知道名稱即可，例如：使用 CNN 卷積神經網路做影像分類)
#
# ### 作業 3：資料來源
#
#
# ### - [Google AI blog](https://ai.googleblog.com/)
#
# ### - [Facebook Research blog](https://research.fb.com/blog/)
#
# ### - [Apple machine learning journal](https://machinelearning.apple.com/)
#
# ### - [機器之心](https://www.jiqizhixin.com/)
#
# ### - [雷鋒網](https://www.leiphone.com/category/ai)

# %% [markdown]
# ---
#
# ### 1：目標 (要解決什麼問題）
# > 在環境聲源干擾較多的情況下，優化 Siri 正確地識別聲音的表現
#
# ### 2：方法 / 使用的技術 (只需知道名稱即可，例如：使用 CNN 卷積神經網路做影像分類)
# > 多聲道迴聲消除（MCEC）算法 + deep neural network (DNN)
#
# ### 3：資料來源
#
# > [Apple machine learning journal](https://machinelearning.apple.com/) >>
#
# > [Optimizing Siri on HomePod in Far‑Field Settings](https://machinelearning.apple.com/2018/12/03/optimizing-siri-on-homepod-in-far-field-settings.html)

# %% [markdown]
# ## 參考資料
#
#
# ML 流程 by Google - [The 7 Steps of Machine Learning (AI Adventures)](https://www.youtube.com/watch?v=nKW8Ndu7Mjw)

# %% [markdown]
# ### 7 Steps of Machine Learning
#
# 1. Gathering Data
#
# 2. Preparing that Data
#
# 3. Choosing a Model
#
# 4. Training
#
# 5. Evaluation
#
# 6. Hyperparameter Tuning
#
# 7. Prediction

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('nKW8Ndu7Mjw', width=720, height=480) # https://www.youtube.com/watch?v=nKW8Ndu7Mjw
